# %%
import pandas as pd

raw_df = pd.read_csv("../data/complaints.csv")
raw_df.head()
# Out:
#   Date received                                            Product  \
# 0      01/20/25  Credit reporting or other personal consumer re...
# 1      01/11/25  Credit reporting or other personal consumer re...
# 2      01/09/25  Credit reporting or other personal consumer re...
# 3      02/11/25  Credit reporting or other personal consumer re...
# 4      01/23/25  Credit reporting or other personal consumer re...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting                        Improper use of your report
# 1  Credit reporting  Problem with a company's investigation into an...
# 2  Credit reporting               Incorrect information on your report
# 3  Credit reporting               Incorrect information on your report
# 4  Credit reporting               Incorrect information on your report
#
#                                            Sub-issue  \
# 0      Reporting company used your report improperly
# 1  Their investigation did not fix an error on yo...
# 2                           Account status incorrect
# 3                Information belongs to someone else
# 4                Information belongs to someone else
#
#                         Consumer complaint narrative  \
# 0  Iam filling this complaint because XXXX has re...
# 1  LexisNexis sent me an email today at approxima...
# 2  My account with XXXX XXXX TRANSUNION was never...
# 3  I am a victim of XXXX. The information listed ...
# 4  PLEASE BLOCKED AND REMOVED I respectfully requ...
#
#                              Company public response  \
# 0                                                NaN
# 1                                                NaN
# 2  Company has responded to the consumer and the ...
# 3  Company has responded to the consumer and the ...
# 4  Company has responded to the consumer and the ...
#
#                                   Company State ZIP code Tags  \
# 0                           EQUIFAX, INC.    NC    28269  NaN
# 1                              LEXISNEXIS    NJ    088XX  NaN
# 2  TRANSUNION INTERMEDIATE HOLDINGS, INC.    GA    310XX  NaN
# 3  TRANSUNION INTERMEDIATE HOLDINGS, INC.    WI    53590  NaN
# 4     Experian Information Solutions Inc.    TN    38128  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web             01/20/25
# 1           Consent provided           Web             01/11/25
# 2           Consent provided           Web             01/09/25
# 3           Consent provided           Web             02/11/25
# 4           Consent provided           Web             01/23/25
#
#       Company response to consumer Timely response?  Consumer disputed?  \
# 0  Closed with non-monetary relief              Yes                 NaN
# 1          Closed with explanation              Yes                 NaN
# 2  Closed with non-monetary relief              Yes                 NaN
# 3  Closed with non-monetary relief              Yes                 NaN
# 4          Closed with explanation              Yes                 NaN
#
#    Complaint ID
# 0      11611687
# 1      11479904
# 2      11446168
# 3      12038221
# 4      11688896

# %%
# extract only the columns that are relevant to project objective
df = raw_df[['Date received', 'Consumer complaint narrative', 'Company', 'Issue']].copy()
df.columns = ['date_received', 'narrative', 'company', 'issue']

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116945 entries, 0 to 116944
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   date_received  116945 non-null  object
#  1   narrative      116945 non-null  object
#  2   company        116945 non-null  object
#  3   issue          116945 non-null  object
# dtypes: object(4)
# memory usage: 3.6+ MB

# %%
# offical categories (9 labels)
df["issue"].value_counts()
# Out:
# issue
# Incorrect information on your report                               55062
# Problem with a company's investigation into an existing problem    33508
# Improper use of your report                                        26393
# Unable to get your credit report or credit score                     642
# Credit monitoring or identity theft protection services              609
# Problem with fraud alerts or security freezes                        500
# Problem with a company's investigation into an existing issue        194
# Identity theft protection or other monitoring services                36
# Problem with a purchase shown on your statement                        1
# Name: count, dtype: int64

# %%
# top 5 companies being complained 
df["company"].value_counts()[:5]
# Out:
# company
# TRANSUNION INTERMEDIATE HOLDINGS, INC.    38826
# Experian Information Solutions Inc.       36299
# EQUIFAX, INC.                             31272
# CAPITAL ONE FINANCIAL CORPORATION           567
# CITIBANK, N.A.                              438
# Name: count, dtype: int64

# %%
df["date_received"] = pd.to_datetime(df["date_received"], format="%m/%d/%y")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116945 entries, 0 to 116944
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   date_received  116945 non-null  datetime64[ns]
#  1   narrative      116945 non-null  object
#  2   company        116945 non-null  object
#  3   issue          116945 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.6+ MB

# %%
df.head()
# Out:
#   date_received                                          narrative  \
# 0    2025-01-20  Iam filling this complaint because XXXX has re...
# 1    2025-01-11  LexisNexis sent me an email today at approxima...
# 2    2025-01-09  My account with XXXX XXXX TRANSUNION was never...
# 3    2025-02-11  I am a victim of XXXX. The information listed ...
# 4    2025-01-23  PLEASE BLOCKED AND REMOVED I respectfully requ...
#
#                                   company  \
# 0                           EQUIFAX, INC.
# 1                              LEXISNEXIS
# 2  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# 3  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# 4     Experian Information Solutions Inc.
#
#                                                issue
# 0                        Improper use of your report
# 1  Problem with a company's investigation into an...
# 2               Incorrect information on your report
# 3               Incorrect information on your report
# 4               Incorrect information on your report

# %% [markdown]
# # Text Preprocessing
#
# - lowercase
# - remove punctuation, number, short filler words

# %%
import spacy

nlp = spacy.load("en_core_web_sm", disable=["ner", "parser"])

# Modify stopwords to preserve negations
from spacy.lang.en.stop_words import STOP_WORDS

# Define words to keep
negations = {"no", "not", "n't", "never", "none"}
whitelist = {"against"}
custom_stopwords = STOP_WORDS - negations - whitelist

# %%
def clean_text_spacy(text):
    # lowercase
    doc = nlp(text.lower())
    
    tokens = []
    for token in doc:
        # Keep negations as-is
        if token.text in {"not", "no", "n't", "never", "none"}:
            tokens.append(token.text)
        # Then apply rest of filters
        elif token.is_alpha and token.text not in custom_stopwords and len(token) > 2:
            tokens.append(token.lemma_)
    
    # merge the cleaned tokens to a long string as processed narrative
    return " ".join(tokens)

# %%
df_sample = df.sample(10, random_state=42).copy()
df_sample['clean_narrative'] = df_sample['narrative'].apply(clean_text_spacy)

df_sample.head()
# Out:
#       date_received                                          narrative  \
# 59704    2025-02-05  Im filing a complaint against Equifax for fall...
# 2744     2025-02-06  XXXX XXXX XXXX XXXX XXXX XXXX. \nXXXX XXXX, NJ...
# 85458    2025-01-19  Hello, to whom it may concern, I could write o...
# 63838    2025-01-31  I don't remember dates, but I have tried to di...
# 79736    2025-01-17  This CFPB complaint has been filed to request ...
#
#                                       company  \
# 59704     Experian Information Solutions Inc.
# 2744                NAVY FEDERAL CREDIT UNION
# 85458     Experian Information Solutions Inc.
# 63838                           EQUIFAX, INC.
# 79736  TRANSUNION INTERMEDIATE HOLDINGS, INC.
#
#                                                    issue  \
# 59704  Problem with a company's investigation into an...
# 2744                Incorrect information on your report
# 85458                        Improper use of your report
# 63838  Problem with a company's investigation into an...
# 79736               Incorrect information on your report
#
#                                          clean_narrative
# 59704  file complaint against equifax fall properly i...
# 2744   xxxx xxxx xxxx xxxx xxxx xxxx xxxx xxxx xxxx x...
# 85458  hello concern write bunch fair credit reportin...
# 63838  n't remember date try dispute update item xxxx...
# 79736  cfpb complaint file request pursuant fcra tran...

# %%
df['clean_narrative'] = df['narrative'].apply(clean_text_spacy)

# %%
df.to_csv("../data/cleaned_complaints.csv", index=False)
